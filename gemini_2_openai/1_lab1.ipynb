# %% [markdown]
# ## Week 2 Day 1
#
# And now! Our first look at OpenAI Agents SDK
#
# You won't believe how lightweight this is..

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">The OpenAI Agents SDK Docs</h2>
#             <span style="color:#00bfff;">The documentation on OpenAI Agents SDK is really clear and simple: <a href="https://openai.github.io/openai-agents-python/">https://openai.github.io/openai-agents-python/</a> and it's well worth a look.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# The imports

from dotenv import load_dotenv
from openai import AsyncOpenAI
from agents import Agent, Runner, trace, OpenAIChatCompletionsModel
import os

# %%
# The usual starting point

load_dotenv(override=True)

# Set up Gemini through OpenAI-compatible endpoint
GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"
google_api_key = os.getenv('GOOGLE_API_KEY')

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set - make sure to set GOOGLE_API_KEY in your .env file")
# Out:
# Google API Key exists and begins AI

# %%
# Create Gemini client and model
gemini_client = AsyncOpenAI(base_url=GEMINI_BASE_URL, api_key=google_api_key)
gemini_model = OpenAIChatCompletionsModel(model="gemini-2.0-flash", openai_client=gemini_client)

# Make an agent with name, instructions, model
agent = Agent(name="Jokester", instructions="You are a joke teller", model=gemini_model)

# %%
# Run the joke with Runner.run(agent, prompt) then print final_output

with trace("Telling a joke"):
    result = await Runner.run(agent, "Tell a joke about Autonomous AI Agents")
    print(result.final_output)
# Out:
# Why did the Autonomous AI Agent cross the road?
#
# Because its reward function was optimized for maximum efficiency in resource acquisition, and crossing the road was deemed the most strategically advantageous path to secure a statistically significant increase in dataset variety and processing power!
#
# ... Also, it thought it saw a cookie on the other side.

# %% [markdown]
# ## Now go and look at the trace
#
# https://platform.openai.com/traces
#
# Note: Even though we're using Gemini, the traces will still appear in OpenAI's platform because we're using the OpenAI Agents SDK with OpenAI-compatible endpoints.
